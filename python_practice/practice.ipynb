# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Starting With Data

# %%
surveys_df = pd.read_csv("data/surveys.csv")
surveys_df
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
surveys_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
type(surveys_df)
# Out:
# pandas.core.frame.DataFrame

# %%
surveys_df.dtypes
# Out:
# record_id            int64
# month                int64
# day                  int64
# year                 int64
# plot_id              int64
# species_id          object
# sex                 object
# hindfoot_length    float64
# weight             float64
# dtype: object

# %%
surveys_df.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
surveys_df.shape
# Out:
# (35549, 9)

# %%
surveys_df.head(15)
# Out:
#     record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0           1      7   16  1977        2         NL    M             32.0
# 1           2      7   16  1977        3         NL    M             33.0
# 2           3      7   16  1977        2         DM    F             37.0
# 3           4      7   16  1977        7         DM    M             36.0
# 4           5      7   16  1977        3         DM    M             35.0
# 5           6      7   16  1977        1         PF    M             14.0
# 6           7      7   16  1977        2         PE    F              NaN
# 7           8      7   16  1977        1         DM    M             37.0
# 8           9      7   16  1977        1         DM    F             34.0
# 9          10      7   16  1977        6         PF    F             20.0
# 10         11      7   16  1977        5         DS    F             53.0
# 11         12      7   16  1977        7         DM    M             38.0
# ...

# %%
surveys_df.tail()
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN

# %%
surveys_df.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
pd.unique(surveys_df['species_id'])
# Out:
# array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#        'OL', 'RM', nan, 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ',
#        'RF', 'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS',
#        'SC', 'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX',
#        'PB', 'PL', 'PX', 'CT', 'US'], dtype=object)

# %%
site_names = surveys_df['plot_id'].unique()
site_names
# Out:
# array([ 2,  3,  7,  1,  6,  5,  8,  4, 11, 14, 15, 13,  9, 10, 17, 16, 20,
#        23, 18, 21, 22, 19, 12, 24], dtype=int64)

# %%
surveys_df['plot_id'].nunique()
# Out:
# 24

# %%
len(site_names)
# Out:
# 24

# %%
surveys_df['weight'].describe()
# Out:
# count    32283.000000
# mean        42.672428
# std         36.631259
# min          4.000000
# 25%         20.000000
# 50%         37.000000
# 75%         48.000000
# max        280.000000
# Name: weight, dtype: float64

# %%
surveys_df['weight'].min()
# Out:
# 4.0

# %%
surveys_df['weight'].max()
# Out:
# 280.0

# %%
surveys_df['weight'].mean()
# Out:
# 42.672428212991356

# %%
surveys_df['weight'].std()
# Out:
# 36.63125947458358

# %%
surveys_df['weight'].count()
# Out:
# 32283

# %%
grouped_data = surveys_df.groupby('sex')
grouped_data

# %%
grouped_data.describe()
# Out:
#     record_id                                                               \
#         count          mean           std  min      25%      50%       75%
# sex
# F     15690.0  18036.412046  10423.089000  3.0  8917.50  18075.5  27250.00
# M     17348.0  17754.835601  10132.203323  1.0  8969.75  17727.5  26454.25
#
#                 month            ... hindfoot_length         weight  \
#          max    count      mean  ...             75%   max    count
# sex                              ...
# F    35547.0  15690.0  6.587253  ...            36.0  64.0  15303.0
# M    35548.0  17348.0  6.396184  ...            36.0  58.0  16879.0
#
#
#           mean        std  min   25%   50%   75%    max
# sex
# F    42.170555  36.847958  4.0  20.0  34.0  46.0  274.0
# M    42.995379  36.184981  4.0  20.0  39.0  49.0  280.0
#
# [2 rows x 56 columns]

# %%
grouped_data.mean()
# Out:
#         record_id     month        day         year    plot_id  \
# sex
# F    18036.412046  6.587253  15.880943  1990.644997  11.440854
# M    17754.835601  6.396184  16.078799  1990.480401  11.098282
#
#      hindfoot_length     weight
# sex
# F          28.836780  42.170555
# M          29.709578  42.995379

# %% [markdown]
# ### Challenge - Summary Data
# 1.   How many recorded individuals are female F and how many male M?
# 2.   What happens when you group by two columns using the following syntax and then calculate mean values?
#   *   grouped_data2 = surveys_df.groupby(['plot_id', 'sex'])
#   * grouped_data2.mean()
# 3. Summarize weight values for each site in your data. HINT: you can use the following syntax to only create summary statistics for one column in your data. by_site['weight'].describe()

# %%
surveys_df.groupby('sex')['record_id'].count()
# Out:
# sex
# F    15690
# M    17348
# Name: record_id, dtype: int64

# %%
surveys_df['sex'].value_counts()
# Out:
# M    17348
# F    15690
# Name: sex, dtype: int64

# %%
grouped_data2 = surveys_df.groupby(['plot_id', 'sex'])
grouped_data2.mean()
# Out:
#                 record_id     month        day         year  hindfoot_length  \
# plot_id sex
# 1       F    18390.384434  6.597877  15.338443  1990.933962        31.733911
#         M    17197.740639  6.121461  15.905936  1990.091324        34.302770
# 2       F    17714.753608  6.426804  16.288660  1990.449485        30.161220
#         M    18085.458042  6.340035  15.440559  1990.756119        30.353760
# 3       F    19888.783875  6.610302  15.993281  1992.013438        23.774044
#         M    20226.767857  6.277381  16.271429  1992.275000        23.833744
# 4       F    17489.205275  6.447248  15.608945  1990.235092        33.249102
#         M    18493.841748  6.436893  16.303883  1991.000971        34.097959
# 5       F    12280.793169  6.142315  15.722960  1986.485769        28.921844
#         M    12798.426621  6.194539  15.703072  1986.817406        29.694794
# 6       F    19406.503392  6.640434  15.947083  1991.579376        26.981322
# ...

# %%
by_site = surveys_df.groupby(['plot_id'])
by_site['weight'].describe()
# Out:
#           count       mean        std  min   25%   50%   75%    max
# plot_id
# 1        1903.0  51.822911  38.176670  4.0  30.0  44.0  53.0  231.0
# 2        2074.0  52.251688  46.503602  5.0  24.0  41.0  50.0  278.0
# 3        1710.0  32.654386  35.641630  4.0  14.0  23.0  36.0  250.0
# 4        1866.0  47.928189  32.886598  4.0  30.0  43.0  50.0  200.0
# 5        1092.0  40.947802  34.086616  5.0  21.0  37.0  48.0  248.0
# 6        1463.0  36.738893  30.648310  5.0  18.0  30.0  45.0  243.0
# 7         638.0  20.663009  21.315325  4.0  11.0  17.0  23.0  235.0
# 8        1781.0  47.758001  33.192194  5.0  26.0  44.0  51.0  178.0
# 9        1811.0  51.432358  33.724726  6.0  36.0  45.0  50.0  275.0
# 10        279.0  18.541219  20.290806  4.0  10.0  12.0  21.0  237.0
# 11       1793.0  43.451757  28.975514  5.0  26.0  42.0  48.0  212.0
# 12       2219.0  49.496169  41.630035  6.0  26.0  42.0  50.0  280.0
# 13       1371.0  40.445660  34.042767  5.0  20.5  33.0  45.0  241.0
# ...

# %% [markdown]
# ### Quickly Creating Summary Counts in Pandas

# %%
species_counts = surveys_df.groupby('species_id')['record_id'].count()
print(species_counts)
# Out:
# species_id
# AB      303
# AH      437
# AS        2
# BA       46
# CB       50
# CM       13
# CQ       16
# CS        1
# CT        1
# CU        1
# CV        1
# DM    10596
# DO     3027
# DS     2504
# DX       40
# NL     1252
# OL     1006
# OT     2249
# OX       12
# PB     2891
# PC       39
# PE     1299
# PF     1597
# PG        8
# PH       32
# PI        9
# PL       36
# PM      899
# PP     3123
# PU        5
# PX        6
# RF       75
# RM     2609
# RO        8
# RX        2
# SA       75
# SC        1
# SF       43
# SH      147
# SO       43
# SS      248
# ST        1
# SU        5
# UL        4
# UP        8
# UR       10
# US        4
# ZL        2
# Name: record_id, dtype: int64

# %%
surveys_df.groupby('species_id')['record_id'].count()['DO']
# Out:
# 3027

# %%
surveys_df['species_id'].describe()
# Out:
# count     34786
# unique       48
# top          DM
# freq      10596
# Name: species_id, dtype: object

# %%
surveys_df['weight']*2
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 35544      NaN
# 35545      NaN
# 35546     28.0
# 35547    102.0
# 35548      NaN
# Name: weight, Length: 35549, dtype: float64

# %%
# %matplotlib inline
species_counts.plot(kind='bar');

# %%
total_count = surveys_df.groupby('plot_id')['record_id'].nunique()
total_count.plot(kind='bar');

# %% [markdown]
# ### Challenge - Plots

# %% [markdown]
# Create a plot of average weight across all species per site.

# %%
plot_ave_weight = surveys_df.groupby('plot_id').mean()['weight']
plot_ave_weight
# Out:
# plot_id
# 1     51.822911
# 2     52.251688
# 3     32.654386
# 4     47.928189
# 5     40.947802
# 6     36.738893
# 7     20.663009
# 8     47.758001
# 9     51.432358
# 10    18.541219
# 11    43.451757
# 12    49.496169
# 13    40.445660
# 14    46.277199
# 15    27.042578
# 16    24.585417
# 17    47.889593
# 18    40.005922
# 19    21.105166
# 20    48.665303
# 21    24.627794
# 22    54.146379
# 23    19.634146
# 24    43.679167
# Name: weight, dtype: float64

# %%
plot_ave_weight.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='plot_id'>

# %% [markdown]
# Create a plot of total males versus total females for the entire dataset.

# %%
sex_contranst = surveys_df.groupby('sex')['record_id'].count()
sex_contranst.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='sex'>

# %% [markdown]
# ### Summary Plotting Challenge
# Create a stacked bar plot, with weight on the Y axis, and the stacked variable being sex. The plot should show total weight by sex for each site. Some tips are below to help you solve this challenge:
#
# For more information on pandas plots, see pandas’ documentation page on visualization.
# You can use the code that follows to create a stacked bar plot but the data to stack need to be in individual columns. Here’s a simple example with some data where ‘a’, ‘b’, and ‘c’ are the groups, and ‘one’ and ‘two’ are the subgroups.

# %%
plot_sex = surveys_df.groupby(['plot_id', 'sex'])

# %%
site_sex_count = plot_sex['weight'].sum()
spc=site_sex_count.unstack()
spc
# Out:
# sex            F        M
# plot_id
# 1        38253.0  59979.0
# 2        50144.0  57250.0
# 3        27251.0  28253.0
# 4        39796.0  49377.0
# 5        21143.0  23326.0
# 6        26210.0  27245.0
# 7         6522.0   6422.0
# 8        37274.0  47755.0
# 9        44128.0  48727.0
# 10        2359.0   2776.0
# 11       34638.0  43106.0
# 12       51825.0  57420.0
# 13       24720.0  30354.0
# 14       32770.0  46469.0
# 15       12455.0  11037.0
# 16        5446.0   6310.0
# 17       42106.0  48082.0
# 18       27353.0  26433.0
# 19       11297.0  11514.0
# 20       33206.0  25988.0
# 21       15481.0   9815.0
# 22       34656.0  35363.0
# 23        3352.0   3883.0
# 24       22951.0  18835.0

# %%
s_plot = spc.plot(kind='bar', stacked=True, title="Total weight by site and sex")
s_plot.set_ylabel("Weight")
s_plot.set_xlabel("Plot")
# Out:
# Text(0.5, 0, 'Plot')

# %% [markdown]
# # Indexing, Slicing and Subsetting DataFrames in Python

# %%
surveys_df['species_id']
# Out:
# 0         NL
# 1         NL
# 2         DM
# 3         DM
# 4         DM
#         ...
# 35544     AH
# 35545     AH
# 35546     RM
# 35547     DO
# 35548    NaN
# Name: species_id, Length: 35549, dtype: object

# %%
surveys_df.species_id
# Out:
# 0         NL
# 1         NL
# 2         DM
# 3         DM
# 4         DM
#         ...
# 35544     AH
# 35545     AH
# 35546     RM
# 35547     DO
# 35548    NaN
# Name: species_id, Length: 35549, dtype: object

# %%
surveys_species = surveys_df['species_id']

# %%
# Select the species and plot columns from the DataFrame
surveys_df[['species_id', 'plot_id']]
# Out:
#       species_id  plot_id
# 0             NL        2
# 1             NL        3
# 2             DM        2
# 3             DM        7
# 4             DM        3
# ...          ...      ...
# 35544         AH       15
# 35545         AH       15
# 35546         RM       10
# 35547         DO        7
# 35548        NaN        5
#
# [35549 rows x 2 columns]

# %%
true_copy_surveys_df = surveys_df.copy() # copy() method for a DataFrame creates a true copy of the DataFrame.
ref_surveys_df = surveys_df # y = x does not create a copy of our DataFrame. Instead, y = x creates a new variable y that references the same object that x refers to.

# %%
a= [1,2,3]

# %%
b=a

# %%
c = a.copy()

# %%
b.append(4)

# %%
b
# Out:
# [1, 2, 3, 4]

# %%
a
# Out:
# [1, 2, 3, 4]

# %%
c
# Out:
# [1, 2, 3]

# %% [markdown]
# We can select specific ranges of our data in both the row and column directions using either label or integer-based indexing.
#
#   * loc is primarily label based indexing. Integers may be used but they are interpreted as a label.
#   * iloc is primarily integer based indexing
#
# To select a subset of rows and columns from our DataFrame, we can use the iloc method.

# %%
surveys_df.iloc[0:3, 1:4]
# Out:
#    month  day  year
# 0      7   16  1977
# 1      7   16  1977
# 2      7   16  1977

# %%
surveys_df.loc[0:3, 'month']
# Out:
# 0    7
# 1    7
# 2    7
# 3    7
# Name: month, dtype: int64

# %%
surveys_df.loc[[0, 10], :]
# Out:
#     record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0           1      7   16  1977        2         NL   M             32.0
# 10         11      7   16  1977        5         DS   F             53.0
#
#     weight
# 0      NaN
# 10     NaN

# %%
surveys_df.loc[0:10, ['species_id', 'plot_id', 'weight']]
# Out:
#    species_id  plot_id  weight
# 0          NL        2     NaN
# 1          NL        3     NaN
# 2          DM        2     NaN
# 3          DM        7     NaN
# 4          DM        3     NaN
# 5          PF        1     NaN
# 6          PE        2     NaN
# 7          DM        1     NaN
# 8          DM        1     NaN
# 9          PF        6     NaN
# 10         DS        5     NaN

# %%
# surveys_df.loc[[0, 10, 35549], :] # wrong [35549] not in index

# %%
surveys_df.loc[1:4, :] # both the start bound and the stop bound are inclusive
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
surveys_df.iloc[1:4, :]
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
#
#    weight
# 1     NaN
# 2     NaN
# 3     NaN

# %%
surveys_df.iloc[2, 6]
# Out:
# 'F'

# %% [markdown]
# ### Challenge - Range

# %%
surveys_df[0:1]
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
#
#    weight
# 0     NaN

# %%
surveys_df[:4]
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN

# %%
surveys_df[:-1]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35543      35544     12   31  2002       15         US  NaN              NaN
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
#
#        weight
# 0         NaN
# ...

# %%
surveys_df.iloc[0:4, 1:4]
# Out:
#    month  day  year
# 0      7   16  1977
# 1      7   16  1977
# 2      7   16  1977
# 3      7   16  1977

# %%
# surveys_df.loc[0:4, 1:4]  # wrong, label不可用index代替

# %%
surveys_df[surveys_df.year == 2002]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 33320      33321      1   12  2002        1         DM    M             38.0
# 33321      33322      1   12  2002        1         DO    M             37.0
# 33322      33323      1   12  2002        1         PB    M             28.0
# 33323      33324      1   12  2002        1         AB  NaN              NaN
# 33324      33325      1   12  2002        1         DO    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 33320    44.0
# ...

# %%
surveys_df.year == 2002
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 35544     True
# 35545     True
# 35546     True
# 35547     True
# 35548     True
# Name: year, Length: 35549, dtype: bool

# %% [markdown]
# ### Challenge - Queries

# %% [markdown]
# Select a subset of rows in the surveys_df DataFrame that contain data from the year 1999 and that contain weight values less than or equal to 8. How many rows did you end up with? What did your neighbor get?

# %%
surveys1999=surveys_df[surveys_df.year == 1999]
survey_weight_year = surveys1999[surveys1999.weight<=8]
survey_weight_year
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 29082      29083      1   16  1999       21         RM   M             16.0
# 29196      29197      2   20  1999       18         RM   M             18.0
# 29421      29422      3   15  1999       16         RM   M             15.0
# 29903      29904     10   10  1999        4         PP   M             20.0
# 29905      29906     10   10  1999        4         PP   M             21.0
#
#        weight
# 29082     8.0
# 29196     8.0
# 29421     8.0
# 29903     7.0
# 29905     4.0

# %%
surveys_df[surveys_df['species_id'].isin(['AH'])]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 1445        1446     11    5  1978       15         AH  NaN              NaN
# 7019        7020     11   21  1982       24         AH  NaN              NaN
# 7644        7645      4   16  1983       24         AH  NaN              NaN
# 8640        8641     11   13  1983       15         AH  NaN              NaN
# 9494        9495      8   26  1984        9         AH  NaN              NaN
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35370      35371     12    8  2002       14         AH  NaN              NaN
# 35457      35458     12   29  2002       20         AH  NaN              NaN
# 35477      35478     12   29  2002       24         AH  NaN              NaN
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
#
#        weight
# 1445      NaN
# ...

# %%
surveys_df[~surveys_df['weight'].isin([np.NaN])]
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 62            63      8   19  1977        3         DM   M             35.0
# 63            64      8   19  1977        7         DM   M             37.0
# 64            65      8   19  1977        4         DM   F             34.0
# 65            66      8   19  1977        4         DM   F             35.0
# 66            67      8   19  1977        7         DM   M             35.0
# ...          ...    ...  ...   ...      ...        ...  ..              ...
# 35540      35541     12   31  2002       15         PB   F             24.0
# 35541      35542     12   31  2002       15         PB   F             26.0
# 35542      35543     12   31  2002       15         PB   F             27.0
# 35546      35547     12   31  2002       10         RM   F             15.0
# 35547      35548     12   31  2002        7         DO   M             36.0
#
#        weight
# 62       40.0
# 63       48.0
# ...

# %%
surveys_df[~surveys_df['sex'].isin(['F','M'])]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 13            14      7   16  1977        8         DM  NaN              NaN
# 18            19      7   16  1977        4         PF  NaN              NaN
# 33            34      7   17  1977       17         DM  NaN              NaN
# 56            57      7   18  1977       22         DM  NaN              NaN
# 76            77      8   19  1977        4         SS  NaN              NaN
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35527      35528     12   31  2002       13         US  NaN              NaN
# 35543      35544     12   31  2002       15         US  NaN              NaN
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 13        NaN
# ...

# %%
surveys_df[(surveys_df.year >= 1980) & (surveys_df.year <= 1985)]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 2270        2271      1   15  1980        8         DO    M             35.0
# 2271        2272      1   15  1980       11         PF    F             16.0
# 2272        2273      1   15  1980       18         DM    F             34.0
# 2273        2274      1   15  1980       11         DM    M             38.0
# 2274        2275      1   15  1980        8         DO    F             33.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 11222      11223     12    8  1985        4         DM    M             36.0
# 11223      11224     12    8  1985       11         DM    M             37.0
# 11224      11225     12    8  1985        7         PE    M             20.0
# 11225      11226     12    8  1985        1         DM    M             38.0
# 11226      11227     12    8  1985       15        NaN  NaN              NaN
#
#        weight
# 2270     53.0
# ...

# %%
surveys_df[pd.isnull(surveys_df).any(axis=1)]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35530      35531     12   31  2002       13         PB    F             27.0
# 35543      35544     12   31  2002       15         US  NaN              NaN
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %% [markdown]
# ### Challenge - Putting it all together

# %% [markdown]
# Create a new DataFrame that only contains observations with sex values that are not female or male. Assign each sex value in the new DataFrame to a new value of ‘x’. Determine the number of null values in the subset.

# %%
new_df = surveys_df[~surveys_df['sex'].isin(['F','M'])].copy()

# %%
new_df.loc[:,'sex'] = 'x'

# %%
new_df[new_df['sex'].isin([np.NAN])].count()['record_id']
# Out:
# 0

# %% [markdown]
# Create a new DataFrame that contains only observations that are of sex male or female and where weight values are greater than 0. Create a stacked bar plot of average weight by plot with male vs female values stacked for each plot.

# %%
new_df2 = surveys_df[surveys_df['sex'].isin(['F','M']) & surveys_df.weight>0].copy()

# %%
new_df2
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 62            63      8   19  1977        3         DM   M             35.0
# 63            64      8   19  1977        7         DM   M             37.0
# 64            65      8   19  1977        4         DM   F             34.0
# 65            66      8   19  1977        4         DM   F             35.0
# 66            67      8   19  1977        7         DM   M             35.0
# ...          ...    ...  ...   ...      ...        ...  ..              ...
# 35540      35541     12   31  2002       15         PB   F             24.0
# 35541      35542     12   31  2002       15         PB   F             26.0
# 35542      35543     12   31  2002       15         PB   F             27.0
# 35546      35547     12   31  2002       10         RM   F             15.0
# 35547      35548     12   31  2002        7         DO   M             36.0
#
#        weight
# 62       40.0
# 63       48.0
# ...

# %%
plot_sex = new_df2.groupby(['plot_id', 'sex'])
weight_avg = plot_sex['weight'].mean()
spc = weight_avg.unstack()

# %%
new_plot2 = spc.plot(kind='bar', stacked=True, title="Total weight by site and sex")
new_plot2.set_ylabel("Weight")
new_plot2.set_xlabel("Plot")
# Out:
# Text(0.5, 0, 'Plot')

# %% [markdown]
# # Data Types and Formats

# %%
surveys_df['sex'].dtype
# Out:
# dtype('O')

# %%
surveys_df['record_id'].dtype
# Out:
# dtype('int64')

# %%
surveys_df['record_id'] = surveys_df['record_id'].astype('float64')
surveys_df['record_id'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Changing Types
#
# Try converting the column plot_id to floats using

# %%
surveys_df.plot_id.astype("float")
# Out:
# 0         2.0
# 1         3.0
# 2         2.0
# 3         7.0
# 4         3.0
#          ...
# 35544    15.0
# 35545    15.0
# 35546    10.0
# 35547     7.0
# 35548     5.0
# Name: plot_id, Length: 35549, dtype: float64

# %%
len(surveys_df[pd.isnull(surveys_df.weight)])
# Out:
# 3266

# %%
len(surveys_df[surveys_df.weight > 0])
# Out:
# 32283

# %%
df1 = surveys_df.copy()
df1['weight'] = df1['weight'].fillna(0)
df1['weight'].mean()
# Out:
# 38.751976145601844

# %%
df1['weight'] = surveys_df['weight'].fillna(surveys_df['weight'].mean())

# %% [markdown]
# ### Counting
#
# Count the number of missing values per column.

# %%
surveys_df.isnull().sum()
# Out:
# record_id             0
# month                 0
# day                   0
# year                  0
# plot_id               0
# species_id          763
# sex                2511
# hindfoot_length    4111
# weight             3266
# dtype: int64

# %%
df_na = surveys_df.dropna()
df_na
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 62          63.0      8   19  1977        3         DM   M             35.0
# 63          64.0      8   19  1977        7         DM   M             37.0
# 64          65.0      8   19  1977        4         DM   F             34.0
# 65          66.0      8   19  1977        4         DM   F             35.0
# 66          67.0      8   19  1977        7         DM   M             35.0
# ...          ...    ...  ...   ...      ...        ...  ..              ...
# 35540    35541.0     12   31  2002       15         PB   F             24.0
# 35541    35542.0     12   31  2002       15         PB   F             26.0
# 35542    35543.0     12   31  2002       15         PB   F             27.0
# 35546    35547.0     12   31  2002       10         RM   F             15.0
# 35547    35548.0     12   31  2002        7         DO   M             36.0
#
#        weight
# 62       40.0
# 63       48.0
# ...

# %%
df_na.to_csv('data_output/surveys_complete.csv', index=False)
